# %% [markdown]
# Iterators
# - iterators are advanced python concepts that allow for efficient looping and memory management.
# - iterators provide a way to access elements of a collections sequentially without exposing the underlying structure.

# %%
my_list = [1, 2, 3, 4, 5, 6]

for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
type(my_list)

print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
## Create iterator using iter() function

iterator = iter(my_list)

print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
# looping through all the element

next(iterator) # print next element in the iterator - if we execute next(iterator) again it will print the next element in the iterator

# after last element, if we execute it again it will raise StopIteration exception
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 3
#       1 # looping through all the element
#       2
# ----> 3 next(iterator) # print next element in the iterator - if we execute next(iterator) again it will print the next element in the iterator
#
# StopIteration:

# %%
## handling StopIteration exception using try-except block

try:
    print(next(iterator))
except StopIteration:
    print("no element")
# Out:
# no element
