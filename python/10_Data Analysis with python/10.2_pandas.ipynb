# %% [markdown]
# Pandas - DataFrame and Series

# %% [markdown]
# - Pandas is a powerful data manipulation library in python, widely used for data analysis and data cleaning.
# - It provides two primary data structures: Series and DataFrame.
# - Series is a **one-dimensional array**-like object, while a DataFrame is a **two-dimensional**, size-mutable, and potentially heterogeneous tavular data structure with labeled axes (rows and columns)

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #### Series

# %%
# A pandas Series is a one-dimensional array-like object that can hold various data types, such as integers, floats, strings, and more. It is similar to a column in a spreadsheet or a database table. Each element in a Series has an associated index, which allows for easy access and manipulation of the data.

data = [10, 20, 30, 40, 50]

# Creating a pandas Series from the data list
series = pd.Series(data)

print("Series: \n", series)
print(type(series))
# Out:
# Series:
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# <class 'pandas.Series'>

# %%
# Creating a pandas Series from dictionary

data = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}

dict_series = pd.Series(data)

print(dict_series)
print(type(dict_series))
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# <class 'pandas.Series'>

# %%
# Creating a pandas Series with custom index

data = [10, 20, 30, 40, 50]

index = ['a', 'b', 'c', 'd', 'e']

pd.Series(data, index=index)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# ##### DataFrame

# %%
"""
DataFrame is a two-dimensional, size-mutable, and heterogeneous tabular data structure with labeled axes (rows and columns). It is similar to a spreadsheet or SQL table, and it can hold various data types, such as integers, floats, strings, and more. Each column in a DataFrame is a pandas Series, and each row can be accessed using its index.
"""

# %%
# Creating a pandas DataFrame from a dictionary of lists

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

# this will create a DataFrame with columns 'Name', 'Age', and 'City', and each row will represent a person with their corresponding information.
df = pd.DataFrame(data)

print("DataFrame from dictionary of lists: \n", df)

print(type(df))
# Out:
# DataFrame from dictionary of lists:
#        Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix
# <class 'pandas.DataFrame'>

# %%
# Create a dataframe from a list of dictionaries

data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'Los Angeles'},
    {'Name': 'Charlie', 'Age': 35, 'City': 'Chicago'},
    {'Name': 'David', 'Age': 40, 'City': 'Houston'},
    {'Name': 'Eva', 'Age': 45, 'City': 'Phoenix'}
]


pf = pd.DataFrame(data)

print("DataFrame from list of dictionaries: \n", pf)

print(type(pf))
# Out:
# DataFrame from list of dictionaries:
#        Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix
# <class 'pandas.DataFrame'>

# %% [markdown]
# #### Read CSV Files

# %%
df = pd.read_csv('sales_data_sample.csv')

df.head() # Display the first 5 rows of the DataFrame
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail() # Display the last 5 rows of the DataFrame
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
## Accessing data from a DataFrame
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix

# %%
print(df['Name']) # Accessing a single column (returns a Series)

print(type(df['Name'])) # Output: <class 'pandas.core.series.Series'>
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# Name: Name, dtype: str
# <class 'pandas.Series'>

# %%
df.loc[0] # Accessing a single row by index (returns a Series)
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
print(df.iloc[0]) # Accessing a single row by index (returns a Series)
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: 0, dtype: object

# %%
## Accessing a specific element

print(df.at[0, 'Name']) # Accessing a specific element by row and column indices
print(df.at[1, 'Name'])

print(df.at[2, "Age"])
# Out:
# Alice
# Bob
# 35

# %%
## Accessing a specific element using 'iat'

print(df.iat[2, 2])
# Out:
# Chicago

# %%
## Data Manipulation with dataframes

df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix

# %%
# Adding a new column 'Salary' to the DataFrame

df['Salary'] = [400000, 500000, 600000, 700000, 800000]
df
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York  400000
# 1      Bob   30  Los Angeles  500000
# 2  Charlie   35      Chicago  600000
# 3    David   40      Houston  700000
# 4      Eva   45      Phoenix  800000

# %%
# Removing a column from the DataFrame
df.drop('Salary', axis=1, inplace=True) # Remove the 'Salary' column

# inplace=True modifies the original DataFrame in place, rather than returning a new DataFrame with the column removed.
# axis=1 specifies that we want to drop a column (axis=0 would be for dropping rows).

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix

# %%
## Add age to the column

# increase the 'Age' column by 1 for all rows in the DataFrame
df['Age'] = df['Age']+1

df
# Out:
#       Name  Age         City
# 0    Alice   26     New York
# 1      Bob   31  Los Angeles
# 2  Charlie   36      Chicago
# 3    David   41      Houston
# 4      Eva   46      Phoenix

# %%
# df.drop(0) # this is not a permanent operation, to make it permanent, we need to use inplace=True

df.drop(0, inplace=True)

# %%
df
# Out:
#       Name  Age         City
# 1      Bob   31  Los Angeles
# 2  Charlie   36      Chicago
# 3    David   41      Houston
# 4      Eva   46      Phoenix

# %%
# Display the data type of each column in the DataFrame
print("Data types: \n", df.dtypes)

# Describe the DataFrame
print("Statistical summary: \n", df.describe())
# Out:
# Data types:
#  Name      str
# Age     int64
# City      str
# dtype: object
# Statistical summary:
#               Age
# count   4.000000
# mean   38.500000
# std     6.454972
# min    31.000000
# 25%    34.750000
# 50%    38.500000
# 75%    42.250000
# max    46.000000
