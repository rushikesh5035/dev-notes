# %% [markdown]
# Standard Library Overview
#
# - python's standard library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box

# %%
import array

arr = array.array('i', [1, 2, 3, 4, 5])

print("Original array:", arr)
# Out:
# Original array: array('i', [1, 2, 3, 4, 5])

# %%
import math

print(math.sqrt(16))  # Returns 4.0
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## Random

import random

print(random.randint(1, 10))

print(random.choice(['apple', 'banana', 'orange', 'cherry']))
# Out:
# 8
# cherry

# %%
## OS - File and Directory Access

import os

print(os.getcwd())  # Get current working directory
# Out:
# e:\dev-notes\python\5_Modules

# %%
os.mkdir('text_dir')

# %%
## High Level Operations on files and collection of files

import shutil

shutil.copyfile("source.txt", "destination.txt")  # Copy a file
# Out:
# 'destination.txt'

# %%
## Data Serialization 
# converting data in json etc. format to be stored in a file or sent over the network

import json

data = {"name": "Rushi", "age": 23}

json_str = json.dumps(data) # convert dict into json
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Rushi", "age": 23}
# <class 'str'>
# {'name': 'Rushi', 'age': 23}
# <class 'dict'>

# %%
## csv

import csv

with open("example.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Age"])
    writer.writerow(["Rushi", 23])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Rushi', '23']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-26 00:17:53.406504
# 2026-07-25 00:17:53.406504

# %%
## time

import time

print(time.time())  # Current time in seconds since epoch

time.sleep(2)
print(time.time()) # Current time after 2 seconds
# Out:
# 1785005402.7835886
# 1785005404.785082

# %%
## regular expressions

import re

pattern = r'\d+'  # Matches one or more digits
text = "There are 123 apples and 456 oranges."

match = re.search(pattern, text)

print(match.group())
# Out:
# 123
