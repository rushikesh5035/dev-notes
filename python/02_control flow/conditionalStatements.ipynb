# %% [markdown]
# #### Conditional Statement

# %% [markdown]
# if Statement

# %%
age = 20

if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %% [markdown]
# else

# %%
age = 16

if age>=18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %% [markdown]
# elif -> allows you to check multiple conditions, it stands for "else if"

# %%
age = 14

if age<13:
    print("You are a child.")
elif age<18:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are a teenager.

# %% [markdown]
# Nested conditional statements

# %%
number = 0

if number > 0:
    print("Number is positive")
    if number % 2 == 0:
        print("Number is even")
    else:
        print("Number is odd")
else:
    print("Number is zero or negative")
# Out:
# Number is zero or negative

# %% [markdown]
# Practical Examples

# %%
## Determine if a year is a leap year or not (year divided by 4)

year = int(input("Enter a year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(year, "is a leap year.")
        else:
            print(year, " is not a leap year.")
    else:
        print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# 2026 is not a leap year.
