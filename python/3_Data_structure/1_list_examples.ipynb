# %% [markdown]
# #### Real World Examples using list

# %% [markdown]
# Example 1: Manafe a Todo List

# %%
to_do_list = ["Buy milk", "Clean the house", "Pay bills"]

## adding a new task to the list
to_do_list.append("Walk the dog")
to_do_list.append("Finish homework")

## adding task on priority basis
to_do_list.insert(0, "Call mom")  # Insert at index 1

## Removing a task after completion task
to_do_list.remove("Clean the house")

## checking if a task is in the list
if "Pay bills" in to_do_list:
    print("Don't forget to pay your bills!")

print("Current to-do list:" )
for task in to_do_list:
    print(f"- {task}")
# Out:
# Don't forget to pay your bills!
# Current to-do list:
# - Call mom
# - Buy milk
# - Pay bills
# - Walk the dog
# - Finish homework

# %% [markdown]
# Example 2: Organizing Student Grades
# - create a list to store and calculate average grades for students

# %%
# Organizing student grades
grades = [85, 92, 78, 90, 88]

# adding new grade
grades.append(95)

# calculating the average grade
average_grade = sum(grades) / len(grades)
print(f"Average grade: {average_grade:.2f}")

# finding the highest and lowest grades

highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average grade: 88.00
# Highest Grade: 95
# Lowest Grade: 78

# %% [markdown]
# Example 3: Managing an Inventory
# - use a list to manage inventory items in a stores

# %%
# managing an inventory
inventory = ["apples", "bananas", "oranges", "grapes"]

# adding new items to the inventory
inventory.append("pears")

# removing item that is out of stock
inventory.remove("bananas")

# Checking if an item is in stock
item = "oranges"

if item in inventory:
    print(f"{item} are in stock.")
else:
    print(f"{item} are out of stock.")

# printing the inventory
print("Current inventory:")
for item in inventory:
    print(f"- {item}")
# Out:
# oranges are in stock.
# Current inventory:
# - apples
# - oranges
# - grapes
# - pears

# %% [markdown]
# Examples 4: Collecting User Feedback
# - use a list to collect and analyze user feedback

# %%
# Collecting user feedback
feedback = ["Great service!", "Could be better.", "Loved the product!", "Not satisfied with the delivery."]

# Adding new feedback
feedback.append("Excellent experience!")

# counting specific feedback
positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive feedback count: {positive_feedback_count}")

# printing all feedback
print("User Feedback: ")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive feedback count: 2
# User Feedback:
# - Great service!
# - Could be better.
# - Loved the product!
# - Not satisfied with the delivery.
# - Excellent experience!
