# %%
import os

# %%
## Create a new directory

new_directory = "package"

os.mkdir(new_directory)

print(f"Directory '{new_directory}' created successfully.")
# Out:
# Directory 'package' created successfully.

# %%
## list all files and directories in the current directory

os.listdir('.')
# Out:
# ['6.1_fileoperation.ipynb',
#  '6.2_filepath.ipynb',
#  'destination.txt',
#  'example.bin',
#  'example.txt',
#  'package']

# %%
## Joining paths

dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(dir_name, file_name)

print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(os.getcwd(), dir_name, file_name)

print(full_path) # with current working directory
# Out:
# e:\dev-notes\python\6_file handling\folder\file.txt

# %%
## check file exist

path="example1.txt"

if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example1.txt' does not exist.

# %%
## checking if a path is a file or directory

path = "example.txt"
# path = "example1.txt"

if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example.txt' is a file.

# %%
## getting the absolute path

relative_path = "example.txt"

absolute_path = os.path.abspath(relative_path)

print(f"The absolute path of '{relative_path}' is: {absolute_path}")
# Out:
# The absolute path of 'example.txt' is: e:\dev-notes\python\6_file handling\example.txt
