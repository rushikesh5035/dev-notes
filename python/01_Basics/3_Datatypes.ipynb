# %% [markdown]
# ### Datatypes

# %%
## Integer

age = 22
type(age)
# Out:
# int

# %%
## floating point datatype

height = 5.3
print(height)
print(type(height))
# Out:
# 5.3
# <class 'float'>

# %%
## String datatype

name = "Rushikesh"
print(name)
print(type(name))
# Out:
# Rushikesh
# <class 'str'>

# %%
## boolean datatype
adult= True
print(adult)
print(type(adult))

is_true = bool(10 > 20)
print(is_true)
# Out:
# True
# <class 'bool'>
# False

# %%
## common errors

# result = "hello" + 5 # concatenate str with only str not int

result = "hello" + str(5) 
result
# Out:
# 'hello5'
