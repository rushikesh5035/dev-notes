# %% [markdown]
# ### Operators

# %%
## Arithmethic Operation

a = 10
b = 5

add_result = a + b
sub_result = a - b
mult_result = a * b
div_result = a / b
floor_div_result = a // b
modulus_result = a%b
exponentiation_result = a**b

print("Addition: ", add_result)
print("Substraction:", sub_result)
print("Multiplication:", mult_result)
print("Division:", div_result)
print("Floor Division:", floor_div_result)
print("Modulus operation:", modulus_result)
print("Exponentiation operation: ", exponentiation_result)
# Out:
# Addition:  15
# Substraction: 5
# Multiplication: 50
# Division: 2.0
# Floor Division: 2
# Modulus operation: 0
# Exponentiation operation:  100000

# %%
10/5
# Out:
# 2.0

# %%
## Comparison Operators

a = 10
b = 10.0

a == b
# Out:
# True

# %%
name1 = "Rushi"
name2 = "rushi"
name3 = "Rushi"

name1 == name2 # case sensitive
# Out:
# False

# %%
## Not Equal to !=

name1 != name3
# Out:
# False

# %%
## Greater than >

num1 = 50
num2 = 60

num1 > num2
# Out:
# False

# %%
## Less than <

num1 = 50
num2 = 60

num1 < num2
# Out:
# True

# %%
# greater than and equals to

num1 = 45
num2 = 45

num1 >= num2
# Out:
# True

# %%
# less than and equals to

num1 = 45
num2 = 45

num1 <= num2
# Out:
# True

# %%
### Logical Operators

# AND 
num1 = 50
num2 = 60
print(num1 > 40 and num2 < 70)

# OR
print(num1 > 60 or num2 < 50)

# not
X=True
print(not X)
# Out:
# True
# False
# False

# %%
## simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

addition = num1 + num2
substraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

print("Addition:", addition)
print("Substraction:", substraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus) 
print("Exponentiation:", exponentiation)
# Out:
# Addition: 142.0
# Substraction: 62.0
# Multiplication: 4080.0
# Division: 2.55
# Floor Division: 2.0
# Modulus: 22.0
# Exponentiation: 2.2080396636148523e+80
